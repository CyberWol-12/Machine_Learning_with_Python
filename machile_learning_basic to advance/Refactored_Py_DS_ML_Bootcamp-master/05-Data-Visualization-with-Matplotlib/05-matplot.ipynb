# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd

# %%
X = np.linspace(0,5,11)
y = x**2

# %%
#functional method
plt.plot(x,y,)
plt.xlabel('X Label')
plt.ylabel('Y Label')
plt.title('Title')

plt.show()

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r')


plt.subplot(1,2,2)
plt.plot(y,x,'b')

# %%
#OO
fig = plt.figure()

axes = fig.add_axes([0.1,0.1,0.8,0.8])
axes.plot(x,y)
axes.set_xlabel('X Label')
axes.set_ylabel('Y Label')
axes.set_Title('Title')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[51], line 8
#       4 axes = fig.add_axes([0.1,0.1,0.8,0.8])
#       5 axes.plot(x,y)
#       6 axes.set_xlabel('X Label')
#       7 axes.set_ylabel('Y Label')
# ----> 8 axes.set_Title('Title')
#
# AttributeError: 'Axes' object has no attribute 'set_Title'

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.2,0.5,0.4,0.3])

axes1.plot(x,y)
axes1.set_title("Larger Plot")

axes2.plot(x,y)
axes2.set_title("Small Plot")
# Out:
# Text(0.5, 1.0, 'Small Plot')

# %%
fig,axes = plt.subplots(nrows = 1,ncols = 2)

# for current_axes in axes:
#     current_axes.plot(x,y)
axes[0].plot(X,y)
axes[0].set_title('First PLot')
axes[1].plot(y,X)
axes[1].set_title('Second Plot')

plt.tight_layout()

# %%
fig,axes = plt.subplots(nrows = 2,ncols = 1,figsize = (8,2))

axes[0].plot(X,y)

axes[1].plot(X,y)

plt.tight_layout()

# %%
fig.savefig('my_picture.png',dpi = 200)

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])
ax.plot(X,y)

ax.set_title('Title')
ax.set_xlabel('Y')
ax.set_ylabel('X')
# Out:
# Text(0, 0.5, 'X')

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,x**2,label = 'X Squared')
ax.plot(x,x**3,label = 'X Cubed')

ax.legend(loc = (0.1,0.1))

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(X,y,color ='#FF8C00',lw = 3,ls = '-',marker = 'o',markersize = 7,markerfacecolor = 'yellow')
