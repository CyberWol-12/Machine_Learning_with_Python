# %%
import pandas as pd
import numpy as np

# %%
! pip install plotly
# Out:
# Collecting plotly
#   Downloading plotly-7.0.0-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: narwhals>=1.15.1 in C:\Users\divya\anaconda3\envs\ml_env\Lib\site-packages (from plotly) (2.23.0)
# Requirement already satisfied: packaging in C:\Users\divya\anaconda3\envs\ml_env\Lib\site-packages (from plotly) (26.1)
# Downloading plotly-7.0.0-py3-none-any.whl (9.1 MB)
#    ---------------------------------------- 0.0/9.1 MB ? eta -:--:--
#    ------------- -------------------------- 3.1/9.1 MB 16.8 MB/s eta 0:00:01
#    ------------------------------------- -- 8.4/9.1 MB 20.7 MB/s eta 0:00:01
#    ---------------------------------------- 9.1/9.1 MB 20.3 MB/s  0:00:00
# Installing collected packages: plotly
# Successfully installed plotly-7.0.0

# %%
# !pip install cufflinks
# Out:
# Collecting cufflinks
#   Downloading cufflinks-0.17.3.tar.gz (81 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy>=1.9.2 in C:\Users\divya\anaconda3\envs\ml_env\Lib\site-packages (from cufflinks) (2.5.1)
# Requirement already satisfied: pandas>=0.19.2 in C:\Users\divya\anaconda3\envs\ml_env\Lib\site-packages (from cufflinks) (3.0.3)
# Requirement already satisfied: plotly>=4.1.1 in C:\Users\divya\anaconda3\envs\ml_env\Lib\site-packages (from cufflinks) (7.0.0)
# Requirement already satisfied: six>=1.9.0 in C:\Users\divya\anaconda3\envs\ml_env\Lib\site-packages (from cufflinks) (1.17.0)
# Collecting colorlover>=0.2.1 (from cufflinks)
#   Downloading colorlover-0.3.0-py3-none-any.whl.metadata (421 bytes)
# Requirement already satisfied: setuptools>=34.4.1 in C:\Users\divya\anaconda3\envs\ml_env\Lib\site-packages (from cufflinks) (83.0.0)
# Requirement already satisfied: ipython>=5.3.0 in C:\Users\divya\anaconda3\envs\ml_env\Lib\site-packages (from cufflinks) (9.15.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in C:\Users\divya\anaconda3\envs\ml_env\Lib\site-packages (from cufflinks) (8.1.7)
# Requirement already satisfied: colorama>=0.4.4 in C:\Users\divya\anaconda3\envs\ml_env\Lib\site-packages (from ipython>=5.3.0->cufflinks) (0.4.6)
# Requirement already satisfied: decorator>=5.1.0 in C:\Users\divya\anaconda3\envs\ml_env\Lib\site-packages (from ipython>=5.3.0->cufflinks) (5.3.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in C:\Users\divya\anaconda3\envs\ml_env\Lib\site-packages (from ipython>=5.3.0->cufflinks) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in C:\Users\divya\anaconda3\envs\ml_env\Lib\site-packages (from ipython>=5.3.0->cufflinks) (0.20.0)
# Requirement already satisfied: matplotlib-inline>=0.1.6 in C:\Users\divya\anaconda3\envs\ml_env\Lib\site-packages (from ipython>=5.3.0->cufflinks) (0.2.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in C:\Users\divya\anaconda3\envs\ml_env\Lib\site-packages (from ipython>=5.3.0->cufflinks) (3.0.53)
# Requirement already satisfied: psutil>=7 in C:\Users\divya\anaconda3\envs\ml_env\Lib\site-packages (from ipython>=5.3.0->cufflinks) (7.2.2)
# Requirement already satisfied: pygments>=2.14.0 in C:\Users\divya\anaconda3\envs\ml_env\Lib\site-packages (from ipython>=5.3.0->cufflinks) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in C:\Users\divya\anaconda3\envs\ml_env\Lib\site-packages (from ipython>=5.3.0->cufflinks) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in C:\Users\divya\anaconda3\envs\ml_env\Lib\site-packages (from ipython>=5.3.0->cufflinks) (5.15.0)
# Requirement already satisfied: wcwidth>=0.1.4 in C:\Users\divya\anaconda3\envs\ml_env\Lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->cufflinks) (0.8.2)
# Requirement already satisfied: comm>=0.1.3 in C:\Users\divya\anaconda3\envs\ml_env\Lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (0.2.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in C:\Users\divya\anaconda3\envs\ml_env\Lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in C:\Users\divya\anaconda3\envs\ml_env\Lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (3.0.16)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in C:\Users\divya\anaconda3\envs\ml_env\Lib\site-packages (from jedi>=0.18.2->ipython>=5.3.0->cufflinks) (0.8.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\divya\anaconda3\envs\ml_env\Lib\site-packages (from pandas>=0.19.2->cufflinks) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\divya\anaconda3\envs\ml_env\Lib\site-packages (from pandas>=0.19.2->cufflinks) (2026.2)
# Requirement already satisfied: narwhals>=1.15.1 in C:\Users\divya\anaconda3\envs\ml_env\Lib\site-packages (from plotly>=4.1.1->cufflinks) (2.23.0)
# Requirement already satisfied: packaging in C:\Users\divya\anaconda3\envs\ml_env\Lib\site-packages (from plotly>=4.1.1->cufflinks) (26.1)
# Requirement already satisfied: executing>=1.2.0 in C:\Users\divya\anaconda3\envs\ml_env\Lib\site-packages (from stack_data>=0.6.0->ipython>=5.3.0->cufflinks) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in C:\Users\divya\anaconda3\envs\ml_env\Lib\site-packages (from stack_data>=0.6.0->ipython>=5.3.0->cufflinks) (3.0.1)
# Requirement already satisfied: pure_eval in C:\Users\divya\anaconda3\envs\ml_env\Lib\site-packages (from stack_data>=0.6.0->ipython>=5.3.0->cufflinks) (0.2.3)
# Downloading colorlover-0.3.0-py3-none-any.whl (8.9 kB)
# Building wheels for collected packages: cufflinks
#   Building wheel for cufflinks (pyproject.toml): started
#   Building wheel for cufflinks (pyproject.toml): finished with status 'done'
#   Created wheel for cufflinks: filename=cufflinks-0.17.3-py3-none-any.whl size=68561 sha256=d2611f4b6952d26c326233935e2475d60b4abeb433b6876ec813f3a2b848e99c
#   Stored in directory: c:\users\divya\appdata\local\pip\cache\wheels\13\bc\65\1ac45445dba1052b5e837dc49f5282c8cb2f934ae9e6f62f0e
# Successfully built cufflinks
# Installing collected packages: colorlover, cufflinks
#
#    ---------------------------------------- 2/2 [cufflinks]
#
# Successfully installed colorlover-0.3.0 cufflinks-0.17.3

# %%
import plotly
print(plotly.__version__)
# Out:
# 7.0.0

# %%
import cufflinks as cf

# %%
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot

# %%
init_notebook_mode(connected = True)
# Out:
#         <script>
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-4.0.0.min"</script>

# %%
cf.go_offline()
# Out:
#         <script>
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-4.0.0.min"</script>

# %%
#Dtaa
df = pd.DataFrame(np.random.randn(100,4),columns = 'A B C D'.split())

# %%
df.head()
# Out:
#           A         B         C         D
# 0 -1.225021 -0.868805 -0.734424  1.051568
# 1 -1.582000  0.019614 -0.447552 -2.610870
# 2 -0.201511 -0.636699 -1.107418 -0.542155
# 3 -0.501770 -0.620274  0.139441  0.224711
# 4 -1.173059 -0.960191 -0.200930 -1.258521
