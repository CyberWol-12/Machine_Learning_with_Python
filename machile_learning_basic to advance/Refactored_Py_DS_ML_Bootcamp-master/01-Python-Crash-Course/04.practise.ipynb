# %%
#int
1
# Out:
# 1

# %%
#dictinoary
d = {'key':'value','key2':123}
d['key']
# Out:
# 'value'

# %%
d['key2']
# Out:
# 123

# %%
d = {'k1':[1,2,3]}

# %%
d
# Out:
# {'k1': [1, 2, 3]}

# %%
#while loop for loop
seq = [1,2,3.4]
for item in seq:
    print(item)
# Out:
# 1
# 2
# 3.4

# %%
i = 1
while i<5:
    print(f"i is:{i}")
    i = i+1
# Out:
# i is:1
# i is:2
# i is:3
# i is:4
