# %%
import chart_studio.plotly as py
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot
import plotly.graph_objs as go
# !pip install chart-studio

# %%
init_notebook_mode(connected = True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
data = dict(type = 'choropleth',locations = ['AZ','CA','NY'],locationmode = 'USA-states',colorscale = 'Portland',text = ['text 1','text 2','text 3'],z = [1.0,2.0,3.0],colorbar = {'title':'Colorbar Title Goes Here'})

# %%
layout = dict(geo = {'scope':'usa'})

# %%
choromap = go.Figure(data = [data],layout = layout)

# %%
iplot(choromap)
# Out:
# <div>                            <div id="0cef9512-8e87-44ee-bfb7-56db8c826b82" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0cef9512-8e87-44ee-bfb7-56db8c826b82")) {                    Plotly.newPlot(                        "0cef9512-8e87-44ee-bfb7-56db8c826b82",                        [{"colorbar":{"title":{"text":"Colorbar Title Goes Here"}},"colorscale":[[0.0,"rgb(12,51,131)"],[0.25,"rgb(10,136,186)"],[0.5,"rgb(242,211,56)"],[0.75,"rgb(242,143,56)"],[1.0,"rgb(217,30,30)"]],"locationmode":"USA-states","locations":["AZ","CA","NY"],"text":["text 1","text 2","text 3"],"z":[1.0,2.0,3.0],"type":"choropleth"}],                        {"geo":{"scope":"usa"},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"
# ...

# %%
import pandas as pd
df = pd.read_csv('2011_us_agri_Exports')

# %%
df.head()
# Out:
#   code        state category  total exports   beef  pork  poultry   dairy  \
# 0   AL      Alabama    state        1390.63   34.4  10.6    481.0    4.06
# 1   AK       Alaska    state          13.31    0.2   0.1      0.0    0.19
# 2   AZ      Arizona    state        1463.17   71.3  17.9      0.0  105.48
# 3   AR     Arkansas    state        3586.02   53.2  29.4    562.9    3.53
# 4   CA   California    state       16472.88  228.7  11.1    225.4  929.95
#
#    fruits fresh  fruits proc  total fruits  veggies fresh  veggies proc  \
# 0           8.0         17.1         25.11            5.5           8.9
# 1           0.0          0.0          0.00            0.6           1.0
# 2          19.3         41.0         60.27          147.5         239.4
# 3           2.2          4.7          6.88            4.4           7.1
# 4        2791.8       5944.6       8736.40          803.2        1303.5
#
#    total veggies  corn  wheat   cotton  \
# 0          14.33  34.9   70.0   317.61
# ...

# %%
data = dict(type = 'choropleth',
              colorscale='YlOrRd',
              locations = df['code'],
              locationmode = 'USA-states',
              z = df['total exports'],
              text = df['text'],
              marker = dict(line = dict(color = 'rgb(255,255,255)',width =2)),
              colorbar = {'title':'Millions USD'})

# %%
layout = dict(title = '2011 US Agricultute Exports By Sates',geo = dict(scope = 'usa',showlakes = True,lakecolor = 'rgb(85,173,240)'))

# %%
layout
# Out:
# {'title': '2011 US Agricultute Exports By Sates',
#  'geo': {'scope': 'usa', 'showlakes': True, 'lakecolor': 'rgb(85,173,240)'}}

# %%
choromap2 = go.Figure(data = [data],layout = layout)

# %%
iplot(choromap2)
# Out:
# <div>                            <div id="78458021-320d-4d3b-b5cb-eddd220e2f08" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("78458021-320d-4d3b-b5cb-eddd220e2f08")) {                    Plotly.newPlot(                        "78458021-320d-4d3b-b5cb-eddd220e2f08",                        [{"colorbar":{"title":{"text":"Millions USD"}},"colorscale":[[0.0,"rgb(255,255,204)"],[0.125,"rgb(255,237,160)"],[0.25,"rgb(254,217,118)"],[0.375,"rgb(254,178,76)"],[0.5,"rgb(253,141,60)"],[0.625,"rgb(252,78,42)"],[0.75,"rgb(227,26,28)"],[0.875,"rgb(189,0,38)"],[1.0,"rgb(128,0,38)"]],"locationmode":"USA-states","locations":["AL","AK","AZ","AR","CA","CO","CT","DE","FL","GA","HI","ID","IL","IN","IA","KS","KY","LA","ME","MD","MA","MI","MN","MS","MO","MT","NE","NV","N
# ...

# %%
df = pd.read_csv('2014_World_GDP')

# %%
df.head()
# Out:
#           COUNTRY  GDP (BILLIONS) CODE
# 0     Afghanistan           21.71  AFG
# 1         Albania           13.40  ALB
# 2         Algeria          227.80  DZA
# 3  American Samoa            0.75  ASM
# 4         Andorra            4.80  AND

# %%
data = dict(type = 'choropleth',
            locations = df['CODE'],
            z = df['GDP (BILLIONS)'],
            text = df['COUNTRY'],
            colorbar = {'title':'GDP in Billions USD'})

# %%
layout = dict(title = '2014 Global GDP',
                geo = dict(showframe = False,
                projection = {'type':'Mercator'}))

# %%
choromap3 = go.Figure(data = [data],layout = layout)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 choromap3 = go.Figure(data = [data],layout = layout)
#
# File c:\Users\divya\anaconda3\envs\ml_env\Lib\site-packages\plotly\graph_objs\_figure.py:629, in Figure.__init__(self, data, layout, frames, skip_invalid, **kwargs)
#     625         ValueError
#     626             if a property in the specification of data, layout, or frames
#     627             is invalid AND skip_invalid is False
#     628         """
# --> 629         super(Figure, self).__init__(data, layout, frames, skip_invalid, **kwargs)
#
# File c:\Users\divya\anaconda3\envs\ml_env\Lib\site-packages\plotly\basedatatypes.py:555, in BaseFigure.__init__(self, data, layout_plotly, frames, skip_invalid, **kwargs)
#     552 self._layout_validator = LayoutValidator()
#     554 # ### Import Layout ###
# ...
