# %%
# !pip install --upgrade --force-reinstall --no-cache-dir narwhals


import sys
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from sklearn.datasets import make_blobs
from sklearn.preprocessing import StandardScaler
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

import umap.umap_ as UMAP

# Import these also
import plotly
import plotly.express as px
import narwhals

print("Narwhals Version:", narwhals.__version__)
print("Narwhals Path:", narwhals.__file__)

print("Plotly Version:", plotly.__version__)
print("Plotly Path:", plotly.__file__)
# Out:
# Collecting narwhals
#   Downloading narwhals-2.24.0-py3-none-any.whl.metadata (15 kB)
# Downloading narwhals-2.24.0-py3-none-any.whl (461 kB)
# Installing collected packages: narwhals
#   Attempting uninstall: narwhals
#     Found existing installation: narwhals 2.24.0
#     Uninstalling narwhals-2.24.0:
#       Successfully uninstalled narwhals-2.24.0
# Successfully installed narwhals-2.24.0
# Narwhals Version: 1.31.0
# Narwhals Path: c:\Users\divya\anaconda3\Lib\site-packages\narwhals\__init__.py
# Plotly Version: 6.7.0
# Plotly Path: c:\Users\divya\anaconda3\Lib\site-packages\plotly\__init__.py
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\divya\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\divya\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\divya\anaconda3\Lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sklearn-compat 0.1.3 requires scikit-learn<1.7,>=1.2, but you have scikit-learn 1.9.0 which is incompatible.

# %%
# CLuster centers:
centers = [ [ 2, -6, -6],
            [-1,  9,  4],
            [-8,  7,  2],
            [ 4,  7,  9] ]

# Cluster standard deviations:
cluster_std=[1,1,2,3.5]

# Make the blobs and return the data and the blob labels
X, labels_ = make_blobs(n_samples=500, centers=centers, n_features=3, cluster_std=cluster_std, random_state=42)

# %%
df = pd.DataFrame(X, columns=['X', 'Y', 'Z'])

# Create interactive 3D scatter plot
fig = px.scatter_3d(df, x='X', y='Y', z='Z', color=labels_.astype(str) ,  opacity=0.7,  color_discrete_sequence=px.colors.qualitative.G10, title="3D Scatter Plot of Four Blobs")

fig.update_traces(marker=dict(size=5, line=dict(width=1, color='black')), showlegend=False)
fig.update_layout(coloraxis_showscale=False, width=1000, height=800)  # Remove color bar, resize plot

fig.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[43], line 4
#       1 df = pd.DataFrame(X, columns=['X', 'Y', 'Z'])
#       3 # Create interactive 3D scatter plot
# ----> 4 fig = px.scatter_3d(df, x='X', y='Y', z='Z', color=labels_.astype(str) ,  opacity=0.7,  color_discrete_sequence=px.colors.qualitative.G10, title="3D Scatter Plot of Four Blobs")
#       6 fig.update_traces(marker=dict(size=5, line=dict(width=1, color='black')), showlegend=False)
#       7 fig.update_layout(coloraxis_showscale=False, width=1000, height=800)  # Remove color bar, resize plot
#
# File c:\Users\divya\anaconda3\Lib\site-packages\plotly\express\_chart_types.py:776, in scatter_3d(data_frame, x, y, z, color, symbol, size, text, hover_name, hover_data, custom_data, error_x, error_x_minus, error_y, error_y_minus, error_z, error_z_minus, animation_frame, animation_group, category_orders, labels, size_max, color_discrete_sequence, color_discrete_map, color_continuous_scale, range_color, color_continuous_midpoint, symbol_sequence, symbol_map, opacity, log_x, log_y, log_z, range_x, range_y, range_z, title, template, width, height)
#     730 def scatter_3d(
#     731     data_frame=None,
#     732     x=None,
#    (...)
#     770     height=None,
#     771 ) -> go.Figure:
#     772     """
#     773     In a 3D scatter plot, each row of `data_frame` is represented by a
#     774     symbol mark in 3D space.
#     775     """
# --> 776     return make_figure(args=locals(), constructor=go.Scatter3d)
#
# File c:\Users\divya\anaconda3\Lib\site-packages\plotly\express\_core.py:2300, in make_figure(args, constructor, trace_patch, layout_patch)
#    2295         group[var] = 100.0 * group[var] / group_sum
#    2297 patch, fit_results = make_trace_kwargs(
#    2298     args, trace_spec, group, mapping_labels.copy(), sizeref
#    2299 )
# -> 2300 trace.update(patch)
#    2301 if fit_results is not None:
#    2302     trendline_rows.append(mapping_labels.copy())
#
# File c:\Users\divya\anaconda3\Lib\site-packages\plotly\basedatatypes.py:5133, in BasePlotlyType.update(self, dict1, overwrite, **kwargs)
#    5131         BaseFigure._perform_update(self, kwargs, overwrite=overwrite)
#    5132 else:
# -> 5133     BaseFigure._perform_update(self, dict1, overwrite=overwrite)
#    5134     BaseFigure._perform_update(self, kwargs, overwrite=overwrite)
#    5136 return self
#
# File c:\Users\divya\anaconda3\Lib\site-packages\plotly\basedatatypes.py:3934, in BaseFigure._perform_update(plotly_obj, update_obj, overwrite)
#    3931                 plotly_obj[key] = val
#    3932         else:
#    3933             # Assign non-compound value
# -> 3934             plotly_obj[key] = val
#    3936 elif isinstance(plotly_obj, tuple):
#    3938     if len(update_obj) == 0:
#    3939         # Nothing to do
#
# File c:\Users\divya\anaconda3\Lib\site-packages\plotly\basedatatypes.py:4868, in BasePlotlyType.__setitem__(self, prop, value)
#    4864         self._set_array_prop(prop, value)
#    4866     # ### Handle simple property ###
#    4867     else:
# -> 4868         self._set_prop(prop, value)
#    4869 else:
#    4870     # Make sure properties dict is initialized
#    4871     self._init_props()
#
# File c:\Users\divya\anaconda3\Lib\site-packages\plotly\basedatatypes.py:5207, in BasePlotlyType._set_prop(self, prop, val)
#    5204 validator = self._get_validator(prop)
#    5206 try:
# -> 5207     val = validator.validate_coerce(val)
#    5208 except ValueError as err:
#    5209     if self._skip_invalid:
#
# File c:\Users\divya\anaconda3\Lib\site-packages\_plotly_utils\basevalidators.py:420, in validate_coerce(self, v)
#     416 class EnumeratedValidator(BaseValidator):
#     417     """
#     418     "enumerated": {
#     419         "description": "Enumerated value type. The available values are
# --> 420                         listed in `values`.",
#     421         "requiredOpts": [
#     422             "values"
#     423         ],
#     424         "otherOpts": [
#     425             "dflt",
#     426             "coerceNumber",
#     427             "arrayOk"
#     428         ]
#     429     },
#     430     """
#     432     def __init__(
#     433         self,
#     434         plotly_name,
#    (...)
#     439         **kwargs,
#     440     ):
#     441         super(EnumeratedValidator, self).__init__(
#     442             plotly_name=plotly_name, parent_name=parent_name, **kwargs
#     443         )
#
# File c:\Users\divya\anaconda3\Lib\site-packages\_plotly_utils\basevalidators.py:110, in copy_to_readonly_numpy_array(v, kind, force_numeric)
#     106                 # Series.dt.to_pydatetime will return Index[object]
#     107                 # https://github.com/pandas-dev/pandas/pull/52459
#     108                 v = np.array(v.dt.to_pydatetime())
#     109         else:
# --> 110             # DatetimeIndex
#     111             v = v.to_pydatetime()
#     112 elif pd and isinstance(v, pd.DataFrame) and len(set(v.dtypes)) == 1:
#
# File c:\Users\divya\anaconda3\Lib\site-packages\narwhals\stable\v1\__init__.py:1619, in from_native(native_object, strict, pass_through, eager_only, eager_or_interchange_only, series_only, allow_series)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File c:\Users\divya\anaconda3\Lib\site-packages\narwhals\translate.py:511, in _from_native_impl(native_object, pass_through, eager_only, eager_or_interchange_only, series_only, allow_series, version)
#     489 def get_native_namespace(*obj: Frame | Series[Any] | IntoFrame | IntoSeries) -> Any:
#     490     """Get native namespace from object.
#     491
#     492     Arguments:
#    (...)
#     509         <module 'polars'...>
#     510     """
# --> 511     if not obj:
#     512         msg = "At least one object must be passed to `get_native_namespace`."
#     513         raise ValueError(msg)
#
# File c:\Users\divya\anaconda3\Lib\site-packages\narwhals\_pandas_like\series.py:7
#       4 import warnings
#       5 from typing import TYPE_CHECKING, Any, Literal, overload
# ----> 7 from narwhals._compliant import EagerSeries, EagerSeriesHist
#       8 from narwhals._pandas_like.series_cat import PandasLikeSeriesCatNamespace
#       9 from narwhals._pandas_like.series_dt import PandasLikeSeriesDateTimeNamespace
#
# ImportError: cannot import name 'EagerSeriesHist' from 'narwhals._compliant' (c:\Users\divya\anaconda3\Lib\site-packages\narwhals\_compliant\__init__.py)
