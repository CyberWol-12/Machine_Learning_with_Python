# %%
# !pip install numpy==2.2.0
# !pip install pandas==2.2.3
# !pip install matplotlib==3.9.3
# !pip install plotly==5.24.1
# !pip install --upgrade scikit-learn umap-learn

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.datasets import make_blobs
from sklearn.preprocessing import StandardScaler

import umap.umap_ as UMAP 
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

import plotly.express as px
from sklearn.datasets import make_blobs
# Out:
# Collecting numpy==2.2.0
#   Downloading numpy-2.2.0-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Downloading numpy-2.2.0-cp313-cp313-win_amd64.whl (12.6 MB)
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    --------------------- ------------------ 6.8/12.6 MB 35.1 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 31.1 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.5
#     Uninstalling numpy-2.2.5:
#       Successfully uninstalled numpy-2.2.5
# Successfully installed numpy-2.2.0
# Requirement already satisfied: pandas==2.2.3 in c:\users\divya\anaconda3\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\divya\anaconda3\lib\site-packages (from pandas==2.2.3) (2.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\divya\anaconda3\lib\site-packages (from pandas==2.2.3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\divya\anaconda3\lib\site-packages (from pandas==2.2.3) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\divya\anaconda3\lib\site-packages (from pandas==2.2.3) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\divya\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas==2.2.3) (1.17.0)
# Collecting matplotlib==3.9.3
#   Downloading matplotlib-3.9.3-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\divya\anaconda3\lib\site-packages (from matplotlib==3.9.3) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\divya\anaconda3\lib\site-packages (from matplotlib==3.9.3) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\divya\anaconda3\lib\site-packages (from matplotlib==3.9.3) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\divya\anaconda3\lib\site-packages (from matplotlib==3.9.3) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\divya\anaconda3\lib\site-packages (from matplotlib==3.9.3) (2.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\divya\anaconda3\lib\site-packages (from matplotlib==3.9.3) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\divya\anaconda3\lib\site-packages (from matplotlib==3.9.3) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\divya\anaconda3\lib\site-packages (from matplotlib==3.9.3) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\divya\anaconda3\lib\site-packages (from matplotlib==3.9.3) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\divya\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib==3.9.3) (1.17.0)
# Downloading matplotlib-3.9.3-cp313-cp313-win_amd64.whl (7.8 MB)
#    ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#    ---------------------------- ----------- 5.5/7.8 MB 28.9 MB/s eta 0:00:01
#    ---------------------------------------- 7.8/7.8 MB 23.5 MB/s eta 0:00:00
# Installing collected packages: matplotlib
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.10.0
#     Uninstalling matplotlib-3.10.0:
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'c:\\users\\divya\\anaconda3\\lib\\site-packages\\matplotlib\\backends\\_backend_agg.cp313-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.
# Collecting plotly==5.24.1
#   Downloading plotly-5.24.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\divya\anaconda3\lib\site-packages (from plotly==5.24.1) (9.0.0)
# Requirement already satisfied: packaging in c:\users\divya\anaconda3\lib\site-packages (from plotly==5.24.1) (24.2)
# Downloading plotly-5.24.1-py3-none-any.whl (19.1 MB)
#    ---------------------------------------- 0.0/19.1 MB ? eta -:--:--
#    ----------- ---------------------------- 5.2/19.1 MB 26.4 MB/s eta 0:00:01
#    ------------------------ --------------- 11.5/19.1 MB 28.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 16.8/19.1 MB 27.5 MB/s eta 0:00:01
#    ---------------------------------------- 19.1/19.1 MB 25.5 MB/s eta 0:00:00
# Installing collected packages: plotly
#   Attempting uninstall: plotly
#     Found existing installation: plotly 6.7.0
#     Uninstalling plotly-6.7.0:
#       Successfully uninstalled plotly-6.7.0
# Successfully installed plotly-5.24.1
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\divya\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\divya\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\divya\anaconda3\Lib\site-packages)
# Requirement already satisfied: scikit-learn in c:\users\divya\anaconda3\lib\site-packages (1.6.1)
# Collecting scikit-learn
#   Downloading scikit_learn-1.9.0-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Collecting umap-learn
#   Downloading umap_learn-0.5.12-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: numpy>=1.24.1 in c:\users\divya\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\divya\anaconda3\lib\site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.4.0 in c:\users\divya\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Collecting narwhals>=2.0.1 (from scikit-learn)
#   Downloading narwhals-2.24.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: threadpoolctl>=3.5.0 in c:\users\divya\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: numba>=0.51.2 in c:\users\divya\anaconda3\lib\site-packages (from umap-learn) (0.61.2)
# Collecting pynndescent>=0.5 (from umap-learn)
#   Downloading pynndescent-0.6.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: tqdm in c:\users\divya\anaconda3\lib\site-packages (from umap-learn) (4.67.1)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in c:\users\divya\anaconda3\lib\site-packages (from numba>=0.51.2->umap-learn) (0.44.0)
# Requirement already satisfied: colorama in c:\users\divya\anaconda3\lib\site-packages (from tqdm->umap-learn) (0.4.6)
# Downloading scikit_learn-1.9.0-cp313-cp313-win_amd64.whl (8.2 MB)
#    ---------------------------------------- 0.0/8.2 MB ? eta -:--:--
#    ------------------- -------------------- 3.9/8.2 MB 19.1 MB/s eta 0:00:01
#    ---------------------------------------  8.1/8.2 MB 20.7 MB/s eta 0:00:01
#    ---------------------------------------- 8.2/8.2 MB 19.5 MB/s eta 0:00:00
# Downloading umap_learn-0.5.12-py3-none-any.whl (91 kB)
# Downloading narwhals-2.24.0-py3-none-any.whl (461 kB)
# Downloading pynndescent-0.6.0-py3-none-any.whl (73 kB)
# Installing collected packages: narwhals, scikit-learn, pynndescent, umap-learn
#
#   Attempting uninstall: narwhals
#
#     Found existing installation: narwhals 1.31.0
#
#     Uninstalling narwhals-1.31.0:
#
#       Successfully uninstalled narwhals-1.31.0
#
#    ---------------------------------------- 0/4 [narwhals]
#    ---------------------------------------- 0/4 [narwhals]
#    ---------------------------------------- 0/4 [narwhals]
#    ---------------------------------------- 0/4 [narwhals]
#    ---------------------------------------- 0/4 [narwhals]
#    ---------------------------------------- 0/4 [narwhals]
#    ---------------------------------------- 0/4 [narwhals]
#   Attempting uninstall: scikit-learn
#    ---------------------------------------- 0/4 [narwhals]
#     Found existing installation: scikit-learn 1.6.1
#    ---------------------------------------- 0/4 [narwhals]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#     Uninstalling scikit-learn-1.6.1:
#    ---------- ----------------------------- 1/4 [scikit-learn]
#       Successfully uninstalled scikit-learn-1.6.1
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [scikit-learn]
#    -------------------- ------------------- 2/4 [pynndescent]
#    ---------------------------------------- 4/4 [umap-learn]
#
# Successfully installed narwhals-2.24.0 pynndescent-0.6.0 scikit-learn-1.9.0 umap-learn-0.5.12
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\divya\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\divya\anaconda3\Lib\site-packages)
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\divya\anaconda3\Lib\site-packages\~klearn'.
#   You can safely remove it manually.
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\divya\anaconda3\Lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sklearn-compat 0.1.3 requires scikit-learn<1.7,>=1.2, but you have scikit-learn 1.9.0 which is incompatible.
